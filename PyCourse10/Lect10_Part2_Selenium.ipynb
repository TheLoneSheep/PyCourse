# %% [markdown]
# # Web-scraping: сбор данных из баз данных и интернет-источников
#
# *Алла Тамбовцева*
#
#
# ## Управление браузером с Selenium: введение

# %% [markdown]
# ### Установка и подготовка к работе

# %% [markdown]
# Библиотека Selenium – библиотека для управления браузером с помощью Python. Она позволяет запускать браузер и имитировать действия пользователя в нём.
#
# Зачем это может понадобиться? Во-первых, такое «встраивание» в браузер в большинстве случаев позволяет решить проблему с возникающими капчами и иными ограничениями, так как настройки сайта не распознают, что запрос к исходному коду страницы производится автоматически. Во-вторых, необходимость имитации действий в браузере неизбежно возникает при обработке динамических веб-страниц, где некоторые элементы (окна, графики, таблицы) появляются только при определенных действиях пользователя, например, при скроллинге или наведении мышкой. В-третьих, библиотека может быть полезна в случаях, если доступ к API сайта или базы данных получить довольно сложно, но при работе в браузере информация доступна (в таком случае можем залогиниться через Python как пользователь и потихоньку выгружать данные).
#
# Установим библиотеку:

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.27.1-py3-none-any.whl (9.7 MB)
# Collecting trio~=0.17
#   Downloading trio-0.27.0-py3-none-any.whl (481 kB)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in d:\anaconda3\lib\site-packages (from selenium) (1.26.7)
# Collecting websocket-client~=1.8
#   Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Collecting typing_extensions~=4.9
#   Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Requirement already satisfied: certifi>=2021.10.8 in d:\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Collecting sniffio>=1.3.0
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: idna in d:\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Collecting attrs>=23.2.0
#   Downloading attrs-25.1.0-py3-none-any.whl (63 kB)
# Collecting outcome
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: sortedcontainers in d:\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in d:\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: pycparser in d:\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in d:\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: attrs, sniffio, outcome, h11, exceptiongroup, wsproto, trio, websocket-client, typing-extensions, trio-websocket, selenium
#   Attempting uninstall: attrs
#     Found existing installation: attrs 21.2.0
#     Uninstalling attrs-21.2.0:
#       Successfully uninstalled attrs-21.2.0
#   Attempting uninstall: sniffio
#     Found existing installation: sniffio 1.2.0
#     Uninstalling sniffio-1.2.0:
#       Successfully uninstalled sniffio-1.2.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
# Successfully installed attrs-25.1.0 exceptiongroup-1.2.2 h11-0.14.0 outcome-1.3.0.post0 selenium-4.27.1 sniffio-1.3.1 trio-0.27.0 trio-websocket-0.12.2 typing-extensions-4.12.2 websocket-client-1.8.0 wsproto-1.2.0

# %% [markdown]
# **NB.** Если библиотека уже установлена, команда выше вернет большой текст с сообщениями вида `Requirement already satisfied`, если не помните, когда успели ее установить, лучше принудительно обновить версию на всякий случай:
#
#     !pip install selenium --upgrade
#
# Зачем? В новой версии библиотека `selenium` при первом запуске браузера из Python сама скачает подходящий драйвер для соединения с браузером и будет использовать его в дальнейшем, а в старых версиях будет искать файл с драйвером на компьютере и выдавать ошибку.

# %% [markdown]
# Сначала импортируем библиотеку полностью, проверим, что всё идёт по плану:

# %%
import selenium

# %% [markdown]
# Теперь импортируем отдельные компоненты:
#
# * модуль `webdriver`, нужен непосредственно для запуска браузера через Python;
# * коллекция атрибутов для поиска элементов на странице `By`;
# * коллекция атрибутов для имитации нажатия клавиш `Keys`.

# %%
from selenium import webdriver as wd
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# Запустим браузер Chrome средствами Selenium (в модуле есть функции для разных браузеров, но лучше всего работать с Chrome или Firefox):

# %%
br = wd.Chrome()

# %% [markdown]
# Если вы исполняете код выше первый раз, это может занять некоторое время, так как функция `Chrome()` сначала скачает и установит подходящую версию драйвера для Chrome, который будет обеспечивать связь между Selenium и той версией браузера Chrome, которая установлена у вас на компьютере. В последующие разы всё должно происходить быстрее.
#
# В результате запуска строки выше должно открыться новое окно браузера Chrome. Оно пустое и, скорее всего, с всплывающим предупреждением о том, что браузером управляет автоматизированное тестовое ПО. Это нормально, мы «имитировали» открытие браузера от лица пользователя, теперь, если мы будем в этом окне переходить по ссылкам на сайты, сайты не будут воспринимать запросы как автоматические (в отличие от запросов через модуль `requests`, из-за автоматических или слишком быстрых запросов, собственно, могут возникать те же капчи).
#
# Открывшееся окно браузера в течение работы закрывать нельзя. Python будет там выполнять действия, а мы будем их отслеживать со стороны.
# Приступим к работе.

# %% [markdown]
# Открываем новое окно на всю ширину экрана на случай, если какие-то элементы в маленьком окне будут мешать или накладываться друг на друга (так бывает с рекламой, всплывающими окнами и подобным):

# %%
br.maximize_window()

# %% [markdown]
# ### Поиск элементов на странице

# %% [markdown]
# Начнём с простого примера – сайта книжного магазина «Библио-Глобус». Вообще этот сайт можно парсить и без Selenium, он пока не блокирует автоматические запросы, но зато другие сайты магазинов или онлайн-кинотеатров с похожей структурой умеют это делать.
#
# Отправим запрос – перейдём в открытом окне по ссылке на [главную страницу](https://www.biblio-globus.ru/) сайта:

# %%
br.get("https://www.biblio-globus.ru/")

# %% [markdown]
# В окне должна открыться главная страница сайта. Найдём на странице поле для поиска интересующего товара. Для этого нам понадобится метод `.find_element()`, он применяется к объекту *WebDriver* (у нас `br`). Вообще в Selenium есть два метода для поиска, по аналогии с методами `.find()` и `.find_all()` в BeautifulSoup:
#
# * `.find_element()` – поиск одного элемента, возвращает один результат, если подходящих элементов несколько, возвращается первый;
# * `.find_elements()` – поиск нескольких элементов, возвращает список результатов.
#
# Искать будем по id объекта, его можем найти в исходном коде страницы или через инструменты разработчика.

# %%
search = br.find_element(By.ID, "SearchBooks")

# %% [markdown]
# В инструментах разработчика id объекта отображается с `#`, классы с `.`, в нём же можно запросить более сложный запрос `XPATH`, но об этом поговорим позже. Сейчас в `search` у нас хранится объект Selenium, к которому можно применять различные методы. Так как мы нашли поле для поиска, которое можно заполнять, мы воспользуемся методом `.send_keys()`, который введёт в это поле текст. Запросим книги по Python:

# %%
search.send_keys("python")

# %% [markdown]
# В открытом окне должен появиться текст и выпадающее меню с названиями книг. Магия!
#
# **Примечание.** Если мы нашли объект некорректно, например, не само поле (в HTML обычно с тэгом `<input>`), а рамочку вокруг него или раздел, внутри которого это поле находится, то есть те элементы, которые не подразумевают интерактива в виде ввода значений, в ответ на `.send_keys()` мы получим ошибку `element not interactable`.

# %% [markdown]
# Для активации поиска нужно найти соответствующую кнопку рядом с полем и кликнуть на неё. Но можно поступить проще (не всегда подобные кнопки удобно искать), ведь мы часто вместо кликания просто нажимаем на *Enter*!

# %%
search.send_keys(Keys.ENTER)

# %% [markdown]
# Отлично! Теперь нужно поработать с результатами поиска. Предположим, что мы пишем код – основу для какой-нибудь программы или приложения, которая позволяет пользователю по ключевым словам выполнить поиск и отсортировать результаты по какому-нибудь критерию, доступному на сайте. Например, по цене, от меньшей к большей.
#
# Найдём выпадающее меню с нужными опциями на странице по названию тэга.

# %%
options = br.find_element(By.TAG_NAME, "select")

# %% [markdown]
# По аналогии с предыдущим примером заполнения ввода поля, выбор опций в обычных выпадающих меню с тэгом `<select>` можно осуществить с помощью того же метода `.send_keys()`.

# %%
options.send_keys(" Сначала дешевле ") # обратите внимание на пробелы (так в исходном коде)

# %% [markdown]
# Отлично! Давайте ещё найдём поле для галочки «В наличии» и кликнем на него!

# %%
tick = br.find_element(By.CLASS_NAME, "custom-control-label")
tick.click()

# %% [markdown]
# Технически, нам достаточно извлечь исходный код страницы из открытого браузера и стандартным образом выгрузить необходимую информацию с помощью BeautifulSoup.

# %%
html = br.page_source

# %% [markdown]
# Попробуем найти карточки с найденными товарами!

# %%
from bs4 import BeautifulSoup

# %%
# ну, а тут как всегда,
# вот сами карточки, в следующем практикуме продолжим

soup = BeautifulSoup(html)

# %%
# имеют класс card
# первый элемент – лишний (там не товар, но класс тоже card)

cards = soup.find_all("div", class_ = "card")[1:]

# %% [markdown]
# Для бодрого начала сделаем скриншот той страницы, которая сейчас открыта в окне браузера, запущенном через Selenium, используя метод .save_screenshot().

# %%
# сохраняем в файл test.png
br.save_screenshot("test.png")
# Out:
# True

# %% [markdown]
# Напишем функцию get_cards(), которая принимает на вход строку с кодом HTML, соответствующим странице с результатами запроса (пока это первая страница результатов), и возвращает список объектов BeautifulSoup с карточками товаров (как cards выше).

# %%
def get_cards(html):
    soup = BeautifulSoup(html)
    cards = soup.find_all("div", class_ = "card")
    return cards

# %% [markdown]
# Найдем фрагмент (объект типа WebElement в Selenium) с кнопкой, которая позволяет переходить на следующую страницу поиска, и сохраним его в переменную next_page. Найдем фрагмент с кнопкой , которая позволяет переходить на последнюю страницу поиска, и сохраним его в переменную last_page.

# %%
# поиск по частичному совпадению текста ссылки (» или »»)

next_page = br.find_element(By.PARTIAL_LINK_TEXT, "»")
last_page = br.find_element(By.PARTIAL_LINK_TEXT, "»»")

# %%
# полезные примеры – как понять, что внутри объекта WebElement
# innerHTML – какой код HTML внутри фрагмента last_page

last_page.get_attribute("innerHTML")
# Out:
# '<span aria-hidden="true">»»</span><span class="sr-only">Next</span>'

# %%
# outerHTML – какой код HTML снаружи фрагмента last_page
# в какие тэги он вложен

last_page.get_attribute("outerHTML")
# Out:
# '<a aria-label="Next" class="page-link" href="search?query=python&amp;page=8&amp;sort=5&amp;instock=on&amp;cat=0&amp;isdiscount="><span aria-hidden="true">»»</span><span class="sr-only">Next</span></a>'

# %% [markdown]
# Используя метод .get_attribute(), извлечем из last_page ссылку на последнюю страницу поиска, сохраним ее в переменную last_href.

# %%
last_href = last_page.get_attribute("href")

# %%
print(last_href)
# Out:
# https://www.biblio-globus.ru/catalog/search?query=python&page=8&sort=5&instock=on&cat=0&isdiscount=

# %% [markdown]
# Используя регулярные выражения, извлечем из last_href номер последней страницы с результатами поиска и превратим результат в целое число (тип integer).

# %%
import re

# %%
last_n = int(re.search("page=(\d+)", last_href).group(1))
print(last_n)
# Out:
# 8

# %% [markdown]
# Сделаем, чтобы все страницы с результатами поиска прокликались в открытом окне браузера, а в full_res оказались все карточки с товарами.

# %%
full_res = cards.copy()

for i in range(0, last_n - 1):
    
    next_page = br.find_element(By.PARTIAL_LINK_TEXT, "»")
    next_page.click()
    
    br.implicitly_wait(2)
    
    html = br.page_source
    cards_to_add = get_cards(html)
    full_res.extend(cards_to_add)

# %%
print(len(full_res)) #  число результатов
# Out:
# 93

# %%
full_res
# Out:
# [<div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/11015030">
#  <img alt="Быстрый доступ. Python: советы, функции, подсказки. Шпаргалка-буклет для начинающих (215х285 мм, 6 полос компактного буклета в европодвесе)" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=11015030.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Быстрый доступ. Python: советы,...<br/><span class="card-author">Успенский К.Е. </span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Компактное и удобное руководство для пользователей любого уровня...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">399 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/11015030">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_11015030" onclick="AddToWishlist(11015030)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_11015030" onclick="DeleteFromWishlist(11015030,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10657321">
#  <img alt="Тетрадь общая с пластиковой обложкой на спирали ErichKrause Purple Python, А4, 80 листов, клетка, на резинке" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10657321.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Тетрадь общая с пластиковой...<br/><span class="card-author"> </span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Тетрадь общая формата А4 (220x297 мм). Обложка из высококачественного...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">419 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10657321">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10657321" onclick="AddToWishlist(10657321)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10657321" onclick="DeleteFromWishlist(10657321,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10823441">
#  <img alt="Python глазами хакера" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10823441.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Python глазами хакера<br/><span class="card-author"> </span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Рассмотрены современные интерпретаторы языка Python. Описано...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">509 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10823441">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10823441" onclick="AddToWishlist(10823441)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10823441" onclick="DeleteFromWishlist(10823441,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10882364">
#  <img alt="Практикум по анализу данных на языках Python и R" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10882364.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Практикум по анализу данных на...<br/><span class="card-author">Баюк О. А.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Данное учебное пособие предназначено для студентов очного отделения,...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">509 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10882364">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10882364" onclick="AddToWishlist(10882364)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10882364" onclick="DeleteFromWishlist(10882364,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10983821">
#  <img alt="Python на практике. Войти в IT с нуля" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10983821.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Python на практике. Войти в IT с...<br/><span class="card-author">Кольцов Д. М.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Данная книга поможет вам начать освоение одного из самых...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">619 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10983821">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10983821" onclick="AddToWishlist(10983821)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10983821" onclick="DeleteFromWishlist(10983821,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10992579">
#  <img alt="Python для непрограммистов. Самоучитель в примерах" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10992579.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Python для непрограммистов....<br/><span class="card-author">Коглиати Д. </span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Эта книга в кратчайшие сроки поможет на базовом уровне освоить Python...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">629 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10992579">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10992579" onclick="AddToWishlist(10992579)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10992579" onclick="DeleteFromWishlist(10992579,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/11020239">
#  <img alt="Хакинг на Python + виртуальный диск с кодом" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=11020239.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Хакинг на Python + виртуальный...<br/><span class="card-author">Бухарев Р. С.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Данное практическое руководство по хакингу на Python позволит вам...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">679 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/11020239">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_11020239" onclick="AddToWishlist(11020239)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_11020239" onclick="DeleteFromWishlist(11020239,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10895199">
#  <img alt="Программирование на языке Python. Сложные типы и конструкции" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10895199.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Программирование на языке Python....<br/><span class="card-author">Майков К. А.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Рассмотрены основные практические навыки работы со структурными...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">779 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10895199">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10895199" onclick="AddToWishlist(10895199)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10895199" onclick="DeleteFromWishlist(10895199,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/11001436">
#  <img alt="Нейросети на Python. Основы ИИ и машинного обучения" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=11001436.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Нейросети на Python. Основы ИИ и...<br/><span class="card-author">Куликова И. В.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Эта книга является практическим комплексным гидом по изучению ИИ и...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">799 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/11001436">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_11001436" onclick="AddToWishlist(11001436)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_11001436" onclick="DeleteFromWishlist(11001436,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10938280">
#  <img alt="Начнем. Python. Просто о сложном" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10938280.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Начнем. Python. Просто о сложном<br/><span class="card-author">Иванов С. С.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Данная книга поможет вам в изучении языка программирования...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">809 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10938280">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10938280" onclick="AddToWishlist(10938280)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10938280" onclick="DeleteFromWishlist(10938280,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10933549">
#  <img alt="Для начинающих. Python. 12 уроков для начинающих" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10933549.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Для начинающих. Python. 12 уроков...<br/><span class="card-author">Добряк П. В.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">В 12 уроках показаны основы программирования и базовые конструкции...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">849 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10933549">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10933549" onclick="AddToWishlist(10933549)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10933549" onclick="DeleteFromWishlist(10933549,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/11031408">
#  <img alt="Python. Компьютерные методы обработки информации для анализа данных" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=11031408.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Python. Компьютерные методы...<br/><span class="card-author">Новикова О.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Учебно-методическое пособие "Компьютерные методы обра-ботки...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">969 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/11031408">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_11031408" onclick="AddToWishlist(11031408)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_11031408" onclick="DeleteFromWishlist(11031408,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card sidebar-menu mb-4 cat_bottom">
#  <div class="card-header">
#  <h3 class="h4 card-title">Каталог</h3>
#  </div>
#  <div class="card-body">
#  <ul class="nav nav-pills flex-column category-menu">
#  <li>
#  <a class="nav-link" href="/catalog/index/101">Художественная литература</a>
#  <ul class="list-unstyled">
#  <li><a class="nav-link" href="/Catalog/Index/182">Классическая и современная проза</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/185">Детективы</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/186">Фантастика. Фэнтези</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/189">Любовные романы. Книги о любви </a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6172">Поэзия. Драматургия</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6175">Публицистика. Биографии. Мемуары</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6180">Исторические романы</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6181">Приключения</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6182">Комиксы и манга</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6183">Юмор</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6184">Афоризмы. цитаты</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6185">Фольклор</a></li>
#  </ul>
#  </li>
#  </ul>
#  </div>
#  </div>,
#  <div class="card sidebar-menu mb-4">
#  <div class="card-header">
#  <h3 class="h4 card-title">Каталог</h3>
#  </div>
#  <div class="card-body">
#  <ul class="nav nav-pills flex-column category-menu">
#  <li>
#  <a class="nav-link" href="/catalog/index/101">Художественная литература</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6088">Психология</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6089">Бизнес. Продвижение. Экономика</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2419">Информационные технологии</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6087">Философия. Эзотерика. Религия </a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/192">Гуманитарные и общественные науки</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/193">Естественные науки.  Математика</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/194">Прикладные науки. Техника. Сельское хозяйство</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/200">Книги для детей</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/197">Искусство</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2266">Английский язык</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2267">Немецкий язык</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2268">Французский язык</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2265">Другие языки</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/195">Медицина. Здоровье</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/7">Канцелярские товары</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/196">Хобби. Путешествия. Кулинария</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6191">Юриспруденция. Право</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6270">Спорт. Красота. Здоровье</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2">Учебники</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6">Антиквариат. Товары для Коллекционеров. Букинистика. Подарки</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2009">Постеры. Плакаты. Календари</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6007">Игры</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/4">Аудио/Видео</a>
#  </li>
#  </ul>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10829190">
#  <img alt="Python. Полное руководство" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10829190.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Python. Полное руководство<br/><span class="card-author">Кольцов Д. М.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Эта книга поможет вам освоить язык программирования Python...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">969 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10829190">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10829190" onclick="AddToWishlist(10829190)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10829190" onclick="DeleteFromWishlist(10829190,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10974887">
#  <img alt="Python-интенсив: 50 быстрых упражнений" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10974887.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Python-интенсив: 50 быстрых...<br/><span class="card-author">Реувен  Л.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Автор, Реувен Лернер преподает Python и data science компаниям по...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">1019 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10974887">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10974887" onclick="AddToWishlist(10974887)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10974887" onclick="DeleteFromWishlist(10974887,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10958802">
#  <img alt="Программирование на Python. Первые шаги" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10958802.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Программирование на Python. Первые...<br/><span class="card-author">Щерба А. В.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">В книге описаны базовые конструкции программирования на языке Python:...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">1029 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10958802">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10958802" onclick="AddToWishlist(10958802)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10958802" onclick="DeleteFromWishlist(10958802,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/11027084">
#  <img alt="100 баллов по информатике. Решаем задачи ЕГЭ на языке Python" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=11027084.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">100 баллов по информатике. Решаем...<br/><span class="card-author">Поляков К.Ю.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Данное пособие для подготовки к ЕГЭ по информатике с использованием...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">1079 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/11027084">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_11027084" onclick="AddToWishlist(11027084)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_11027084" onclick="DeleteFromWishlist(11027084,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10926982">
#  <img alt="Python за 7 дней. Краткий курс для начинающих" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10926982.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Python за 7 дней. Краткий курс для...<br/><span class="card-author">Парк Э.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Хотите за одну неделю освоить самый популярный язык программирования?...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><s>1109 ₽</s> <span class="price_item_new price_item_with_discount">776 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10926982">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10926982" onclick="AddToWishlist(10926982)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10926982" onclick="DeleteFromWishlist(10926982,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10855271">
#  <img alt="Python - это просто. Пошаговое руководство по программированию и анализу данных" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10855271.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Python - это просто. Пошаговое...<br/><span class="card-author">Нисчал Н.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Рассмотрены основы синтаксиса языка Python на примере дистрибутива...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">1189 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10855271">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10855271" onclick="AddToWishlist(10855271)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10855271" onclick="DeleteFromWishlist(10855271,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10905509">
#  <img alt="Алгоритмический тренинг. Решения практических задач на Python и C++" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10905509.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Алгоритмический тренинг. Решения...<br/><span class="card-author">Иванов М. </span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Опираясь на богатый соревновательный и эвристический опыт, автор...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">1189 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10905509">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10905509" onclick="AddToWishlist(10905509)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10905509" onclick="DeleteFromWishlist(10905509,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/11013756">
#  <img alt="Python. Погружение в математику с Minecraft" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=11013756.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Python. Погружение в математику с...<br/><span class="card-author">Корягин А.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Дорогой читатель, перед тобой продолжение книги "Python. Великое...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">1219 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/11013756">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_11013756" onclick="AddToWishlist(11013756)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_11013756" onclick="DeleteFromWishlist(11013756,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10981654">
#  <img alt="Python. Красивые задачи для начинающих" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10981654.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Python. Красивые задачи для...<br/><span class="card-author">Добряк П.В.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">В книге приведены примеры решения различных практических задач на...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">1219 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10981654">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10981654" onclick="AddToWishlist(10981654)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10981654" onclick="DeleteFromWishlist(10981654,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10933548">
#  <img alt="Для начинающих. Python, Django и Bootstrap для начинающих" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10933548.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Для начинающих. Python, Django и...<br/><span class="card-author">Постолит А. В.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Книга посвящена вопросам разработки веб-приложений с использованием...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">1239 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10933548">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10933548" onclick="AddToWishlist(10933548)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10933548" onclick="DeleteFromWishlist(10933548,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10898149">
#  <img alt="Надежный Python" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10898149.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Надежный Python<br/><span class="card-author">Виафоре П.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Современные проекты на языке Python непрерывно растут, развиваются и...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">1239 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10898149">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10898149" onclick="AddToWishlist(10898149)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10898149" onclick="DeleteFromWishlist(10898149,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10981653">
#  <img alt="Python. Как стать профессионалом" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10981653.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Python. Как стать профессионалом<br/><span class="card-author">Фаррелл Д.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Книга ориентирована на читателей, имеющих базовый опыт...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">1239 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10981653">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10981653" onclick="AddToWishlist(10981653)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10981653" onclick="DeleteFromWishlist(10981653,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card sidebar-menu mb-4 cat_bottom">
#  <div class="card-header">
#  <h3 class="h4 card-title">Каталог</h3>
#  </div>
#  <div class="card-body">
#  <ul class="nav nav-pills flex-column category-menu">
#  <li>
#  <a class="nav-link" href="/catalog/index/101">Художественная литература</a>
#  <ul class="list-unstyled">
#  <li><a class="nav-link" href="/Catalog/Index/182">Классическая и современная проза</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/185">Детективы</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/186">Фантастика. Фэнтези</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/189">Любовные романы. Книги о любви </a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6172">Поэзия. Драматургия</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6175">Публицистика. Биографии. Мемуары</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6180">Исторические романы</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6181">Приключения</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6182">Комиксы и манга</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6183">Юмор</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6184">Афоризмы. цитаты</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6185">Фольклор</a></li>
#  </ul>
#  </li>
#  </ul>
#  </div>
#  </div>,
#  <div class="card sidebar-menu mb-4">
#  <div class="card-header">
#  <h3 class="h4 card-title">Каталог</h3>
#  </div>
#  <div class="card-body">
#  <ul class="nav nav-pills flex-column category-menu">
#  <li>
#  <a class="nav-link" href="/catalog/index/101">Художественная литература</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6088">Психология</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6089">Бизнес. Продвижение. Экономика</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2419">Информационные технологии</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6087">Философия. Эзотерика. Религия </a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/192">Гуманитарные и общественные науки</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/193">Естественные науки.  Математика</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/194">Прикладные науки. Техника. Сельское хозяйство</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/200">Книги для детей</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/197">Искусство</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2266">Английский язык</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2267">Немецкий язык</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2268">Французский язык</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2265">Другие языки</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/195">Медицина. Здоровье</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/7">Канцелярские товары</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/196">Хобби. Путешествия. Кулинария</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6191">Юриспруденция. Право</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6270">Спорт. Красота. Здоровье</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2">Учебники</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6">Антиквариат. Товары для Коллекционеров. Букинистика. Подарки</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2009">Постеры. Плакаты. Календари</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6007">Игры</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/4">Аудио/Видео</a>
#  </li>
#  </ul>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10943647">
#  <img alt="Основы искусственного интеллекта в примерах на Python. Самоучитель" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10943647.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Основы искусственного интеллекта в...<br/><span class="card-author">Постолит А. В.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Описаны инструментальные средства для разработки приложений...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">1249 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10943647">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10943647" onclick="AddToWishlist(10943647)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10943647" onclick="DeleteFromWishlist(10943647,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10938051">
#  <img alt="Python для Excel" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10938051.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Python для Excel<br/><span class="card-author">Зумштейн Ф.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Книга посвящена автоматизации Excel с помощью языка программирования...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">1319 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10938051">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10938051" onclick="AddToWishlist(10938051)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10938051" onclick="DeleteFromWishlist(10938051,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10519118">
#  <img alt="Python 3   Самое необходимое " class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10519118.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Python 3   Самое необходимое <br/><span class="card-author">Прохоренок Н....</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;"> Описан базовый синтаксис языка Python 3: типы данных, операторы,...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">1329 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10519118">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10519118" onclick="AddToWishlist(10519118)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10519118" onclick="DeleteFromWishlist(10519118,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10969370">
#  <img alt="Мама, не отвлекай. Я Python учу!" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10969370.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Мама, не отвлекай. Я Python учу!<br/><span class="card-author">Лазаревский...</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Эта книга + телефон – все, что нужно ребенку, чтобы полностью...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">1349 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10969370">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10969370" onclick="AddToWishlist(10969370)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10969370" onclick="DeleteFromWishlist(10969370,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/11024695">
#  <img alt="Использование библиотек Python в научных исследованиях" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=11024695.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Использование библиотек Python в...<br/><span class="card-author">Пылькин А. Н.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Рассмотрены основы научных расчетов на языке программирования Python....</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">1359 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/11024695">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_11024695" onclick="AddToWishlist(11024695)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_11024695" onclick="DeleteFromWishlist(11024695,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
# ...
#  <li><a class="nav-link" href="/Catalog/Index/6183">Юмор</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6184">Афоризмы. цитаты</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6185">Фольклор</a></li>
#  </ul>
#  </li>
#  </ul>
#  </div>
#  </div>,
#  <div class="card sidebar-menu mb-4">
#  <div class="card-header">
#  <h3 class="h4 card-title">Каталог</h3>
#  </div>
#  <div class="card-body">
#  <ul class="nav nav-pills flex-column category-menu">
#  <li>
#  <a class="nav-link" href="/catalog/index/101">Художественная литература</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6088">Психология</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6089">Бизнес. Продвижение. Экономика</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2419">Информационные технологии</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6087">Философия. Эзотерика. Религия </a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/192">Гуманитарные и общественные науки</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/193">Естественные науки.  Математика</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/194">Прикладные науки. Техника. Сельское хозяйство</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/200">Книги для детей</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/197">Искусство</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2266">Английский язык</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2267">Немецкий язык</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2268">Французский язык</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2265">Другие языки</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/195">Медицина. Здоровье</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/7">Канцелярские товары</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/196">Хобби. Путешествия. Кулинария</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6191">Юриспруденция. Право</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6270">Спорт. Красота. Здоровье</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2">Учебники</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6">Антиквариат. Товары для Коллекционеров. Букинистика. Подарки</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2009">Постеры. Плакаты. Календари</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6007">Игры</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/4">Аудио/Видео</a>
#  </li>
#  </ul>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/11031733">
#  <img alt="Python: Pandas на практике" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=11031733.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Python: Pandas на практике<br/><span class="card-author">Лернер Р.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">200 упражнений по анализу данных с решениями и пояснениями
#  Библиотека...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">5629 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/11031733">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_11031733" onclick="AddToWishlist(11031733)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_11031733" onclick="DeleteFromWishlist(11031733,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/11006257">
#  <img alt="Введение в статистическое обучение с примерами на PYTHON" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=11006257.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Введение в статистическое обучение...<br/><span class="card-author">Джеймс Г.,...</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Книга доступным для восприятия языком описывает все разнообразие форм...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">5629 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/11006257">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_11006257" onclick="AddToWishlist(11006257)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_11006257" onclick="DeleteFromWishlist(11006257,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10907046">
#  <img alt="Предварительная подготовка данных в PYTHON. Том 1. Инструменты и валидация" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10907046.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Предварительная подготовка данных...<br/><span class="card-author">Груздев А. В.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">В двухтомнике представлены материалы по применению классических...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">5629 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10907046">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10907046" onclick="AddToWishlist(10907046)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10907046" onclick="DeleteFromWishlist(10907046,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card sidebar-menu mb-4 cat_bottom">
#  <div class="card-header">
#  <h3 class="h4 card-title">Каталог</h3>
#  </div>
#  <div class="card-body">
#  <ul class="nav nav-pills flex-column category-menu">
#  <li>
#  <a class="nav-link" href="/catalog/index/101">Художественная литература</a>
#  <ul class="list-unstyled">
#  <li><a class="nav-link" href="/Catalog/Index/182">Классическая и современная проза</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/185">Детективы</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/186">Фантастика. Фэнтези</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/189">Любовные романы. Книги о любви </a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6172">Поэзия. Драматургия</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6175">Публицистика. Биографии. Мемуары</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6180">Исторические романы</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6181">Приключения</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6182">Комиксы и манга</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6183">Юмор</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6184">Афоризмы. цитаты</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6185">Фольклор</a></li>
#  </ul>
#  </li>
#  </ul>
#  </div>
#  </div>,
#  <div class="card sidebar-menu mb-4">
#  <div class="card-header">
#  <h3 class="h4 card-title">Каталог</h3>
#  </div>
#  <div class="card-body">
#  <ul class="nav nav-pills flex-column category-menu">
#  <li>
#  <a class="nav-link" href="/catalog/index/101">Художественная литература</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6088">Психология</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6089">Бизнес. Продвижение. Экономика</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2419">Информационные технологии</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6087">Философия. Эзотерика. Религия </a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/192">Гуманитарные и общественные науки</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/193">Естественные науки.  Математика</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/194">Прикладные науки. Техника. Сельское хозяйство</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/200">Книги для детей</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/197">Искусство</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2266">Английский язык</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2267">Немецкий язык</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2268">Французский язык</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2265">Другие языки</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/195">Медицина. Здоровье</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/7">Канцелярские товары</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/196">Хобби. Путешествия. Кулинария</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6191">Юриспруденция. Право</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6270">Спорт. Красота. Здоровье</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2">Учебники</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6">Антиквариат. Товары для Коллекционеров. Букинистика. Подарки</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/2009">Постеры. Плакаты. Календари</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/6007">Игры</a>
#  </li>
#  <li>
#  <a class="nav-link" href="/catalog/index/4">Аудио/Видео</a>
#  </li>
#  </ul>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/11031733">
#  <img alt="Python: Pandas на практике" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=11031733.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Python: Pandas на практике<br/><span class="card-author">Лернер Р.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">200 упражнений по анализу данных с решениями и пояснениями
#  Библиотека...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">5629 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/11031733">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_11031733" onclick="AddToWishlist(11031733)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_11031733" onclick="DeleteFromWishlist(11031733,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/11006257">
#  <img alt="Введение в статистическое обучение с примерами на PYTHON" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=11006257.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Введение в статистическое обучение...<br/><span class="card-author">Джеймс Г.,...</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">Книга доступным для восприятия языком описывает все разнообразие форм...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">5629 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/11006257">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_11006257" onclick="AddToWishlist(11006257)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_11006257" onclick="DeleteFromWishlist(11006257,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card" style="border:0; box-shadow:none;">
#  <a class="img-wrapper-index" href="/product/10907046">
#  <img alt="Предварительная подготовка данных в PYTHON. Том 1. Инструменты и валидация" class="card-img" src="https://static1.bgshop.ru/imagehandler.ashx?fileName=10907046.jpg&amp;width=200"/>
#  </a>
#  <div class="card-body" style="padding-left:0; padding-right:0;">
#  <div style="height:60px; overflow:hidden; margin-bottom:10px;">
#  <h5 class="card-title" style="font-size:.9rem;">Предварительная подготовка данных...<br/><span class="card-author">Груздев А. В.</span></h5>
#  <p class="card-text d-none" style="font-size:.75rem;">В двухтомнике представлены материалы по применению классических...</p>
#  </div>
#  <div>
#  <div class="price_item_wrapper"><span class="price_item_title">Цена в магазине:</span> <div class="price_item_block"><span class="price_item_new">5629 ₽</span></div></div>
#  </div>
#  <div class="mt-3" style="display: flex; align-items: stretch;">
#  <div>
#  <a class="btn btn-primary" href="/product/10907046">Подробнее</a>
#  </div>
#  <div class="ml-2">
#  <span class="btn btn-light" id="add_wishlist_10907046" onclick="AddToWishlist(10907046)"><i class="far fa-heart" style="color: #aeaeae;"></i></span>
#  <span class="btn btn-light added_wishlist" id="added_wishlist_10907046" onclick="DeleteFromWishlist(10907046,false)"><i class="fas fa-heart" style="color: #d70834;"></i></span>
#  </div>
#  </div>
#  </div>
#  </div>,
#  <div class="card sidebar-menu mb-4 cat_bottom">
#  <div class="card-header">
#  <h3 class="h4 card-title">Каталог</h3>
#  </div>
#  <div class="card-body">
#  <ul class="nav nav-pills flex-column category-menu">
#  <li>
#  <a class="nav-link" href="/catalog/index/101">Художественная литература</a>
#  <ul class="list-unstyled">
#  <li><a class="nav-link" href="/Catalog/Index/182">Классическая и современная проза</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/185">Детективы</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/186">Фантастика. Фэнтези</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/189">Любовные романы. Книги о любви </a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6172">Поэзия. Драматургия</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6175">Публицистика. Биографии. Мемуары</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6180">Исторические романы</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6181">Приключения</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6182">Комиксы и манга</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6183">Юмор</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6184">Афоризмы. цитаты</a></li>
#  <li><a class="nav-link" href="/Catalog/Index/6185">Фольклор</a></li>
#  </ul>
#  </li>
#  </ul>
#  </div>
#  </div>]

# %% [markdown]
# Напишем функцию get_info(), которая принимает на вход карточку товара и возвращает список из следующих элементов:
#
# * название товара (самое полное);
# * ссылка на файл с изображением товара;
# * цена товара (в текстовом формате с указанием валюты);
# * полная ссылка на страницу с полным описанием товара.

# %%
# самое полное название – в альтернативном тексте к изображению (атрибут alt в тэге <img>)
# ссылка на изображение – в источнике изображения (атрибут src в тэге <img>)
# далее ищем подходящие разделы и ссылки, как обычно

def get_info(item):
    
    img = item.find("img")
    name = img.get("alt")
    image_link = img.get("src")
    price = item.find("div", class_ = "price_item_block").text
    link = item.find("a", class_ = "img-wrapper-index").get("href")
        
    return name, price, link, image_link

# %%
full_clean = []

for item in full_res:
    if len(item.get("class")) == 1:
        full_clean.append(item)
        
print(len(full_clean)) # теперь лишнее убрано, элементов меньше
# Out:
# 78

# %%
import pandas as pd

# %%
L = [get_info(item) for item in full_clean]
df = pd.DataFrame(L)
df.head()
# Out:
#                                                    0      1  \
# 0  Быстрый доступ. Python: советы, функции, подск...  399 ₽
# 1  Тетрадь общая с пластиковой обложкой на спирал...  419 ₽
# 2                              Python глазами хакера  509 ₽
# 3   Практикум по анализу данных на языках Python и R  509 ₽
# 4              Python на практике. Войти в IT с нуля  619 ₽
#
#                    2                                                  3
# 0  /product/11015030  https://static1.bgshop.ru/imagehandler.ashx?fi...
# 1  /product/10657321  https://static1.bgshop.ru/imagehandler.ashx?fi...
# 2  /product/10823441  https://static1.bgshop.ru/imagehandler.ashx?fi...
# 3  /product/10882364  https://static1.bgshop.ru/imagehandler.ashx?fi...
# 4  /product/10983821  https://static1.bgshop.ru/imagehandler.ashx?fi...

# %%
# добавляем названия столбцов
df.columns = ["title", "price", "link", "image_link"]

# %%
df
# Out:
#                                                 title   price  \
# 0   Быстрый доступ. Python: советы, функции, подск...   399 ₽
# 1   Тетрадь общая с пластиковой обложкой на спирал...   419 ₽
# 2                               Python глазами хакера   509 ₽
# 3    Практикум по анализу данных на языках Python и R   509 ₽
# 4               Python на практике. Войти в IT с нуля   619 ₽
# ..                                                ...     ...
# 73  Введение в статистическое обучение с примерами...  5629 ₽
# 74  Предварительная подготовка данных в PYTHON. То...  5629 ₽
# 75                         Python: Pandas на практике  5629 ₽
# 76  Введение в статистическое обучение с примерами...  5629 ₽
# 77  Предварительная подготовка данных в PYTHON. То...  5629 ₽
#
#                  link                                         image_link
# 0   /product/11015030  https://static1.bgshop.ru/imagehandler.ashx?fi...
# 1   /product/10657321  https://static1.bgshop.ru/imagehandler.ashx?fi...
# 2   /product/10823441  https://static1.bgshop.ru/imagehandler.ashx?fi...
# 3   /product/10882364  https://static1.bgshop.ru/imagehandler.ashx?fi...
# 4   /product/10983821  https://static1.bgshop.ru/imagehandler.ashx?fi...
# ..                ...                                                ...
# 73  /product/11006257  https://static1.bgshop.ru/imagehandler.ashx?fi...
# 74  /product/10907046  https://static1.bgshop.ru/imagehandler.ashx?fi...
# 75  /product/11031733  https://static1.bgshop.ru/imagehandler.ashx?fi...
# 76  /product/11006257  https://static1.bgshop.ru/imagehandler.ashx?fi...
# 77  /product/10907046  https://static1.bgshop.ru/imagehandler.ashx?fi...
#
# [78 rows x 4 columns]
